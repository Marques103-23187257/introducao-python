# %% [markdown]
# # Exercícios
#
# ## 1. Faturamento do Melhor e do Pior Mês do Ano
#
# Qual foi o valor de vendas do melhor mês do Ano?
# E valor do pior mês do ano?

# %%
meses = ['jan', 'fev', 'mar', 'abr', 'mai', 'jun', 'jul', 'ago', 'set', 'out', 'nov', 'dez']
vendas_1sem = [25000, 29000, 22200, 17750, 15870, 19900]
vendas_2sem = [19850, 20120, 17540, 15555, 49051, 9650]

vendas_ano = vendas_1sem.copy()
vendas_ano.extend(vendas_2sem)

# print(vendas_ano)

print('o valor de vendas do melhor mês foi R${}, e o do pior mês foi de R${}'.format(max(vendas_ano), min(vendas_ano)))
# Out:
# o valor de vendas do melhor mês foi R$49051, e o do pior mês foi de R$9650

# %% [markdown]
# ## 2. Continuação
#
# Agora relacione as duas listas para printar 'O melhor mês do ano foi {} com {} vendas' e o mesmo para o pior mês do ano.
#
# Calcule também o faturamento total do Ano e quanto que o melhor mês representou do faturamento total.
#
# Obs: Para o faturamento total, pode usar a função sum(lista) que soma todos os itens de uma lista

# %%
total = sum(vendas_ano)

print(total)

porcentagem = str(round((max(vendas_ano) / total) * 100, 2) ) + '%'

print('O melhor mês do ano foi {} com o faturamento total de R${}, e o do pior mês foi o de {} com o faturaemto total de R${}'.format(meses [vendas_ano.index(max(vendas_ano))], max(vendas_ano), meses [vendas_ano.index(min(vendas_ano))], min(vendas_ano)))

print('O faturamento total foi de R${}, o mês com a melhor da representa o total de {} das vendas do ano.'.format(total, porcentagem))
# Out:
# 261486
# O melhor mês do ano foi nov com o faturamento total de R$49051, e o do pior mês foi o de dez com o faturaemto total de R$9650
# O faturamento total foi de R$261486, o mês com a melhor da representa o total de 18.76% das vendas do ano.

# %% [markdown]
# ## 3. Crie uma lista com o top 3 valores de vendas do ano (sem fazer "no olho")
#
# Dica: o método remove retira um item da lista.

# %%
top3 = []

vendas_ano_copy = vendas_ano.copy()

for  i in range(3) :
    teste = [vendas_ano_copy.pop(vendas_ano_copy.index(max(vendas_ano_copy)))]
    top3.extend(teste)

print(top3)
# Out:
# [49051, 29000, 25000]
